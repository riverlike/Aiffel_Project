# %% [markdown]
# # Segmentation map으로 도로 이미지 만들기
# ---

# %% [markdown]
# ![d](https://www.secmem.org/assets/images/pix2pix/result1.PNG)

# %%
import numpy
import tensorflow
import os

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 이미지 데이터
# - [cityscapes.zip](https://d3s0tskafalll9.cloudfront.net/media/documents/cityscapes.zip)
#  - 학습용 이미지 : 1000개 (사이즈 : 256, 512, 3)
#  - 평가 이미지 : 5개

# %%
#!unzip '/content/drive/MyDrive/Colab Notebooks/Aiffel/02_Exploration/exp17/data/cityscapes.zip'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/Aiffel/02_Exploration/exp17/data/cityscapes.zip
# replace cityscapes/train/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: nA
# replace cityscapes/train/100.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
data_path = '/content/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))

plt.figure(figsize=(20,15))
for i in range(1, 3):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)
# Out:
# number of train examples : 1000

# %%
#이미지 사이즈 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# 이미지 분할
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# ### Image Augmentation
#  - 훈련용 이미지에 증강적용

# %%
from tensorflow import image

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    #sketch:앞 3채널, colored:뒤 3채널
    return out[...,:3], out[...,3:]

# %% [markdown]
# ### 데이터셋 구성
# - 이미지 증강한 데이터셋과 아닌 데이터넷의 학습 성능비교를 위해 두가지 데이터셋을 설정하여 실험을 진행해보겠다.

# %%
from tensorflow import data

def get_train_org(img_path):
    sketch, colored = load_img(img_path)
    return sketch, colored

def get_train_aug(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)    
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images_org = train_images.map(get_train_org).shuffle(100).batch(4)
train_images_aug = train_images.map(get_train_aug).shuffle(100).batch(4)

# %%
# augmentation sample 확인
sample = train_images_aug.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# pix2pix 모델
# ---
#
# ### Generator
#
# - EncodeBlock(Downsampling Block)
# - DecodeBlock(Upsampling Block)
# - UNetGenerator
#
# ### Discriminator
# - DiscBlock
# - Discriminator
#  - 70x70 PatchGAN을 사용

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  encode_block (EncodeBlock)     (None, 128, 128, 64  3072        ['input_1[0][0]']
#                                 )
#
#  encode_block_1 (EncodeBlock)   (None, 64, 64, 128)  131584      ['encode_block[0][0]']
#
#  encode_block_2 (EncodeBlock)   (None, 32, 32, 256)  525312      ['encode_block_1[0][0]']
#
#  encode_block_3 (EncodeBlock)   (None, 16, 16, 512)  2099200     ['encode_block_2[0][0]']
#
#  encode_block_4 (EncodeBlock)   (None, 8, 8, 512)    4196352     ['encode_block_3[0][0]']
#
#  encode_block_5 (EncodeBlock)   (None, 4, 4, 512)    4196352     ['encode_block_4[0][0]']
#
#  encode_block_6 (EncodeBlock)   (None, 2, 2, 512)    4196352     ['encode_block_5[0][0]']
#
#  encode_block_7 (EncodeBlock)   (None, 1, 1, 512)    4196352     ['encode_block_6[0][0]']
#
#  decode_block (DecodeBlock)     (None, 2, 2, 512)    4196352     ['encode_block_7[0][0]']
#
#  concatenate (Concatenate)      (None, 2, 2, 1024)   0           ['decode_block[0][0]',
#                                                                   'encode_block_6[0][0]']
#
#  decode_block_1 (DecodeBlock)   (None, 4, 4, 512)    8390656     ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 1024)   0           ['decode_block_1[0][0]',
#                                                                   'encode_block_5[0][0]']
#
#  decode_block_2 (DecodeBlock)   (None, 8, 8, 512)    8390656     ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 1024)   0           ['decode_block_2[0][0]',
#                                                                   'encode_block_4[0][0]']
#
#  decode_block_3 (DecodeBlock)   (None, 16, 16, 512)  8390656     ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 1024  0           ['decode_block_3[0][0]',
#                                 )                                 'encode_block_3[0][0]']
#
#  decode_block_4 (DecodeBlock)   (None, 32, 32, 256)  4195328     ['concatenate_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 512)  0           ['decode_block_4[0][0]',
#                                                                   'encode_block_2[0][0]']
#
#  decode_block_5 (DecodeBlock)   (None, 64, 64, 128)  1049088     ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 256)  0           ['decode_block_5[0][0]',
#                                                                   'encode_block_1[0][0]']
#
#  decode_block_6 (DecodeBlock)   (None, 128, 128, 64  262400      ['concatenate_5[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 12  0           ['decode_block_6[0][0]',
#                                 8)                                'encode_block[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 3)  6144       ['concatenate_6[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
Discriminator().get_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 6)  0           ['input_2[0][0]',
#                                                                   'input_3[0][0]']
#
#  disc_block (DiscBlock)         (None, 128, 128, 64  6144        ['concatenate_7[0][0]']
#                                 )
#
#  disc_block_1 (DiscBlock)       (None, 64, 64, 128)  131584      ['disc_block[0][0]']
#
#  disc_block_2 (DiscBlock)       (None, 32, 32, 256)  525312      ['disc_block_1[0][0]']
#
#  disc_block_3 (DiscBlock)       (None, 31, 31, 512)  2099200     ['disc_block_2[0][0]']
#
#  disc_block_4 (DiscBlock)       (None, 30, 30, 1)    8192        ['disc_block_3[0][0]']
#
#  activation (Activation)        (None, 30, 30, 1)    0           ['disc_block_4[0][0]']
#
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# - U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행

# %% [markdown]
# 손실함수 및 옵티마이저 정의
# ---

# %%
from tensorflow.keras import losses
from tensorflow.keras import optimizers

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %% [markdown]
# 학습 및 테스트하기
# ---
#
# 10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질

# %%
generator = UNetGenerator()
discriminator = Discriminator()

def train_unet(train_images, EPOCHS):
    #시각화 데이터 설정
    history = {'g_loss': [], 'l1_loss': [], 'd_loss': [] }

    for epoch in range(1, EPOCHS+1):
        for i, (sketch, colored) in enumerate(train_images):
            g_loss, l1_loss, d_loss = train_step(sketch, colored)
                    
            # 10회 반복마다 손실을 출력합니다.
            if (i+1) % 10 == 0:
                ##시각화 정보 설정
                history['g_loss'].append(g_loss.numpy())
                history['l1_loss'].append(l1_loss.numpy())
                history['d_loss'].append(d_loss.numpy())

                print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                        \tGenerator_loss:{g_loss.numpy():.4f} \
                        \tL1_loss:{l1_loss.numpy():.4f} \
                        \tDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
                
    return history

# %%
history_aug = train_unet(train_images_aug, 10)
# Out:
# EPOCH[1] - STEP[10]                         	Generator_loss:0.8259                         	L1_loss:0.3125                         	Discriminator_loss:1.2743
#
# EPOCH[1] - STEP[20]                         	Generator_loss:0.8742                         	L1_loss:0.2607                         	Discriminator_loss:1.1387
#
# EPOCH[1] - STEP[30]                         	Generator_loss:1.1380                         	L1_loss:0.2844                         	Discriminator_loss:1.0669
#
# EPOCH[1] - STEP[40]                         	Generator_loss:1.0253                         	L1_loss:0.2528                         	Discriminator_loss:1.2175
#
# EPOCH[1] - STEP[50]                         	Generator_loss:1.4046                         	L1_loss:0.2218                         	Discriminator_loss:0.8910
#
# EPOCH[1] - STEP[60]                         	Generator_loss:1.5101                         	L1_loss:0.2186                         	Discriminator_loss:0.6666
#
# EPOCH[1] - STEP[70]                         	Generator_loss:2.0769                         	L1_loss:0.2940                         	Discriminator_loss:0.7568
#
# EPOCH[1] - STEP[80]                         	Generator_loss:1.3149                         	L1_loss:0.2197                         	Discriminator_loss:0.9028
#
# EPOCH[1] - STEP[90]                         	Generator_loss:0.8278                         	L1_loss:0.2497                         	Discriminator_loss:1.2518
#
# EPOCH[1] - STEP[100]                         	Generator_loss:2.2490                         	L1_loss:0.2243                         	Discriminator_loss:0.7180
#
# EPOCH[1] - STEP[110]                         	Generator_loss:1.1861                         	L1_loss:0.3169                         	Discriminator_loss:0.7486
#
# EPOCH[1] - STEP[120]                         	Generator_loss:2.6368                         	L1_loss:0.2313                         	Discriminator_loss:0.9315
#
# EPOCH[1] - STEP[130]                         	Generator_loss:1.3921                         	L1_loss:0.2083                         	Discriminator_loss:0.5140
#
# EPOCH[1] - STEP[140]                         	Generator_loss:1.1336                         	L1_loss:0.2501                         	Discriminator_loss:0.6869
#
# EPOCH[1] - STEP[150]                         	Generator_loss:1.1255                         	L1_loss:0.1862                         	Discriminator_loss:0.8147
#
# EPOCH[1] - STEP[160]                         	Generator_loss:0.8094                         	L1_loss:0.2843                         	Discriminator_loss:0.8355
#
# EPOCH[1] - STEP[170]                         	Generator_loss:1.0052                         	L1_loss:0.2632                         	Discriminator_loss:1.3486
#
# EPOCH[1] - STEP[180]                         	Generator_loss:1.0350                         	L1_loss:0.2203                         	Discriminator_loss:0.9880
#
# EPOCH[1] - STEP[190]                         	Generator_loss:1.8239                         	L1_loss:0.2661                         	Discriminator_loss:0.7341
#
# EPOCH[1] - STEP[200]                         	Generator_loss:1.2994                         	L1_loss:0.2176                         	Discriminator_loss:0.5858
#
# EPOCH[1] - STEP[210]                         	Generator_loss:2.2636                         	L1_loss:0.1996                         	Discriminator_loss:0.4451
#
# EPOCH[1] - STEP[220]                         	Generator_loss:2.3240                         	L1_loss:0.2342                         	Discriminator_loss:0.5083
#
# EPOCH[1] - STEP[230]                         	Generator_loss:1.5265                         	L1_loss:0.2170                         	Discriminator_loss:0.7894
#
# EPOCH[1] - STEP[240]                         	Generator_loss:1.3437                         	L1_loss:0.2527                         	Discriminator_loss:0.5842
#
# EPOCH[1] - STEP[250]                         	Generator_loss:1.8739                         	L1_loss:0.2321                         	Discriminator_loss:0.6504
#
# EPOCH[2] - STEP[10]                         	Generator_loss:2.2441                         	L1_loss:0.2108                         	Discriminator_loss:0.6147
#
# EPOCH[2] - STEP[20]                         	Generator_loss:0.5027                         	L1_loss:0.2810                         	Discriminator_loss:1.2471
#
# EPOCH[2] - STEP[30]                         	Generator_loss:1.1745                         	L1_loss:0.2401                         	Discriminator_loss:0.9082
#
# EPOCH[2] - STEP[40]                         	Generator_loss:1.2576                         	L1_loss:0.2508                         	Discriminator_loss:0.6889
#
# EPOCH[2] - STEP[50]                         	Generator_loss:2.4940                         	L1_loss:0.2126                         	Discriminator_loss:0.4824
#
# EPOCH[2] - STEP[60]                         	Generator_loss:1.4554                         	L1_loss:0.2048                         	Discriminator_loss:0.9483
#
# EPOCH[2] - STEP[70]                         	Generator_loss:1.3968                         	L1_loss:0.2282                         	Discriminator_loss:0.5019
#
# EPOCH[2] - STEP[80]                         	Generator_loss:1.3150                         	L1_loss:0.2177                         	Discriminator_loss:1.2003
#
# EPOCH[2] - STEP[90]                         	Generator_loss:1.6002                         	L1_loss:0.2030                         	Discriminator_loss:0.9034
#
# EPOCH[2] - STEP[100]                         	Generator_loss:1.6877                         	L1_loss:0.2317                         	Discriminator_loss:0.4998
#
# EPOCH[2] - STEP[110]                         	Generator_loss:2.1198                         	L1_loss:0.1980                         	Discriminator_loss:1.4160
#
# EPOCH[2] - STEP[120]                         	Generator_loss:1.8651                         	L1_loss:0.2016                         	Discriminator_loss:1.0175
#
# EPOCH[2] - STEP[130]                         	Generator_loss:1.6022                         	L1_loss:0.1940                         	Discriminator_loss:0.9394
#
# EPOCH[2] - STEP[140]                         	Generator_loss:1.7442                         	L1_loss:0.2085                         	Discriminator_loss:0.9566
#
# EPOCH[2] - STEP[150]                         	Generator_loss:2.3716                         	L1_loss:0.2444                         	Discriminator_loss:1.1117
#
# EPOCH[2] - STEP[160]                         	Generator_loss:0.8563                         	L1_loss:0.1910                         	Discriminator_loss:1.0829
#
# EPOCH[2] - STEP[170]                         	Generator_loss:0.7223                         	L1_loss:0.2266                         	Discriminator_loss:1.1781
#
# EPOCH[2] - STEP[180]                         	Generator_loss:2.5334                         	L1_loss:0.1895                         	Discriminator_loss:0.6313
#
# EPOCH[2] - STEP[190]                         	Generator_loss:1.5440                         	L1_loss:0.2369                         	Discriminator_loss:0.4034
#
# EPOCH[2] - STEP[200]                         	Generator_loss:1.2872                         	L1_loss:0.1951                         	Discriminator_loss:0.6999
#
# EPOCH[2] - STEP[210]                         	Generator_loss:0.9990                         	L1_loss:0.1765                         	Discriminator_loss:0.7989
#
# EPOCH[2] - STEP[220]                         	Generator_loss:1.6485                         	L1_loss:0.2046                         	Discriminator_loss:0.7845
#
# EPOCH[2] - STEP[230]                         	Generator_loss:0.8930                         	L1_loss:0.2237                         	Discriminator_loss:1.0241
#
# EPOCH[2] - STEP[240]                         	Generator_loss:2.4155                         	L1_loss:0.1791                         	Discriminator_loss:0.7968
#
# EPOCH[2] - STEP[250]                         	Generator_loss:1.8578                         	L1_loss:0.2273                         	Discriminator_loss:0.3558
#
# EPOCH[3] - STEP[10]                         	Generator_loss:0.6011                         	L1_loss:0.1820                         	Discriminator_loss:1.0566
#
# EPOCH[3] - STEP[20]                         	Generator_loss:1.5977                         	L1_loss:0.1819                         	Discriminator_loss:0.6958
#
# EPOCH[3] - STEP[30]                         	Generator_loss:2.9270                         	L1_loss:0.1900                         	Discriminator_loss:0.5608
#
# EPOCH[3] - STEP[40]                         	Generator_loss:1.0973                         	L1_loss:0.1843                         	Discriminator_loss:0.7027
#
# EPOCH[3] - STEP[50]                         	Generator_loss:0.6941                         	L1_loss:0.1897                         	Discriminator_loss:1.6018
#
# EPOCH[3] - STEP[60]                         	Generator_loss:0.7384                         	L1_loss:0.2431                         	Discriminator_loss:0.8903
#
# EPOCH[3] - STEP[70]                         	Generator_loss:1.8729                         	L1_loss:0.1712                         	Discriminator_loss:0.5495
#
# EPOCH[3] - STEP[80]                         	Generator_loss:1.4310                         	L1_loss:0.1990                         	Discriminator_loss:0.6409
#
# EPOCH[3] - STEP[90]                         	Generator_loss:0.9464                         	L1_loss:0.2111                         	Discriminator_loss:1.0839
#
# EPOCH[3] - STEP[100]                         	Generator_loss:2.2140                         	L1_loss:0.1884                         	Discriminator_loss:1.5011
#
# EPOCH[3] - STEP[110]                         	Generator_loss:0.9248                         	L1_loss:0.2206                         	Discriminator_loss:0.7491
#
# EPOCH[3] - STEP[120]                         	Generator_loss:2.4106                         	L1_loss:0.2005                         	Discriminator_loss:0.8080
#
# EPOCH[3] - STEP[130]                         	Generator_loss:2.2720                         	L1_loss:0.1508                         	Discriminator_loss:0.7429
#
# EPOCH[3] - STEP[140]                         	Generator_loss:1.8380                         	L1_loss:0.2131                         	Discriminator_loss:0.4225
#
# EPOCH[3] - STEP[150]                         	Generator_loss:0.7540                         	L1_loss:0.2583                         	Discriminator_loss:1.0696
#
# EPOCH[3] - STEP[160]                         	Generator_loss:1.7934                         	L1_loss:0.2097                         	Discriminator_loss:0.3643
#
# EPOCH[3] - STEP[170]                         	Generator_loss:3.0962                         	L1_loss:0.1998                         	Discriminator_loss:0.4509
#
# EPOCH[3] - STEP[180]                         	Generator_loss:1.3038                         	L1_loss:0.1824                         	Discriminator_loss:0.9106
#
# EPOCH[3] - STEP[190]                         	Generator_loss:2.0999                         	L1_loss:0.2093                         	Discriminator_loss:0.2704
#
# EPOCH[3] - STEP[200]                         	Generator_loss:4.0839                         	L1_loss:0.1844                         	Discriminator_loss:1.1657
#
# EPOCH[3] - STEP[210]                         	Generator_loss:2.8411                         	L1_loss:0.2345                         	Discriminator_loss:0.3469
#
# EPOCH[3] - STEP[220]                         	Generator_loss:1.7200                         	L1_loss:0.2045                         	Discriminator_loss:0.3668
#
# EPOCH[3] - STEP[230]                         	Generator_loss:2.0828                         	L1_loss:0.1991                         	Discriminator_loss:0.6655
#
# EPOCH[3] - STEP[240]                         	Generator_loss:2.2302                         	L1_loss:0.1724                         	Discriminator_loss:0.6092
#
# EPOCH[3] - STEP[250]                         	Generator_loss:3.1941                         	L1_loss:0.1997                         	Discriminator_loss:1.2436
#
# EPOCH[4] - STEP[10]                         	Generator_loss:2.2276                         	L1_loss:0.1850                         	Discriminator_loss:0.9234
#
# EPOCH[4] - STEP[20]                         	Generator_loss:1.1972                         	L1_loss:0.2147                         	Discriminator_loss:0.6811
#
# EPOCH[4] - STEP[30]                         	Generator_loss:0.7612                         	L1_loss:0.2135                         	Discriminator_loss:0.7555
#
# EPOCH[4] - STEP[40]                         	Generator_loss:1.8839                         	L1_loss:0.1591                         	Discriminator_loss:0.5240
#
# EPOCH[4] - STEP[50]                         	Generator_loss:2.4442                         	L1_loss:0.1897                         	Discriminator_loss:0.4890
#
# EPOCH[4] - STEP[60]                         	Generator_loss:2.9568                         	L1_loss:0.1852                         	Discriminator_loss:0.9211
#
# EPOCH[4] - STEP[70]                         	Generator_loss:2.7588                         	L1_loss:0.2095                         	Discriminator_loss:0.7572
#
# EPOCH[4] - STEP[80]                         	Generator_loss:1.9347                         	L1_loss:0.1991                         	Discriminator_loss:1.5152
#
# EPOCH[4] - STEP[90]                         	Generator_loss:2.7511                         	L1_loss:0.2100                         	Discriminator_loss:0.2801
#
# EPOCH[4] - STEP[100]                         	Generator_loss:2.4773                         	L1_loss:0.1857                         	Discriminator_loss:1.2025
#
# EPOCH[4] - STEP[110]                         	Generator_loss:1.1792                         	L1_loss:0.2027                         	Discriminator_loss:0.9109
#
# EPOCH[4] - STEP[120]                         	Generator_loss:2.2025                         	L1_loss:0.2331                         	Discriminator_loss:0.7164
#
# EPOCH[4] - STEP[130]                         	Generator_loss:1.7903                         	L1_loss:0.2122                         	Discriminator_loss:0.3829
#
# EPOCH[4] - STEP[140]                         	Generator_loss:3.1129                         	L1_loss:0.2065                         	Discriminator_loss:0.7389
#
# EPOCH[4] - STEP[150]                         	Generator_loss:2.6960                         	L1_loss:0.2379                         	Discriminator_loss:0.5603
#
# EPOCH[4] - STEP[160]                         	Generator_loss:2.2543                         	L1_loss:0.2025                         	Discriminator_loss:0.8337
#
# EPOCH[4] - STEP[170]                         	Generator_loss:1.9443                         	L1_loss:0.1948                         	Discriminator_loss:0.5783
#
# EPOCH[4] - STEP[180]                         	Generator_loss:1.2154                         	L1_loss:0.1747                         	Discriminator_loss:0.8026
#
# EPOCH[4] - STEP[190]                         	Generator_loss:1.5696                         	L1_loss:0.1932                         	Discriminator_loss:0.6248
#
# EPOCH[4] - STEP[200]                         	Generator_loss:2.0311                         	L1_loss:0.2045                         	Discriminator_loss:0.3717
#
# EPOCH[4] - STEP[210]                         	Generator_loss:1.6172                         	L1_loss:0.2014                         	Discriminator_loss:0.6210
#
# EPOCH[4] - STEP[220]                         	Generator_loss:1.0588                         	L1_loss:0.2029                         	Discriminator_loss:1.2808
#
# EPOCH[4] - STEP[230]                         	Generator_loss:2.4919                         	L1_loss:0.1758                         	Discriminator_loss:0.7870
#
# EPOCH[4] - STEP[240]                         	Generator_loss:1.6902                         	L1_loss:0.1862                         	Discriminator_loss:0.9204
#
# EPOCH[4] - STEP[250]                         	Generator_loss:1.3302                         	L1_loss:0.1992                         	Discriminator_loss:0.4790
#
# EPOCH[5] - STEP[10]                         	Generator_loss:2.4085                         	L1_loss:0.1909                         	Discriminator_loss:0.8009
#
# EPOCH[5] - STEP[20]                         	Generator_loss:1.9336                         	L1_loss:0.2373                         	Discriminator_loss:0.4696
#
# EPOCH[5] - STEP[30]                         	Generator_loss:0.5056                         	L1_loss:0.1883                         	Discriminator_loss:1.1265
#
# EPOCH[5] - STEP[40]                         	Generator_loss:1.0132                         	L1_loss:0.1773                         	Discriminator_loss:1.1097
#
# EPOCH[5] - STEP[50]                         	Generator_loss:1.5272                         	L1_loss:0.1806                         	Discriminator_loss:0.7837
#
# EPOCH[5] - STEP[60]                         	Generator_loss:2.3028                         	L1_loss:0.1500                         	Discriminator_loss:1.8365
#
# EPOCH[5] - STEP[70]                         	Generator_loss:3.5815                         	L1_loss:0.1955                         	Discriminator_loss:2.0902
#
# EPOCH[5] - STEP[80]                         	Generator_loss:2.5348                         	L1_loss:0.1801                         	Discriminator_loss:0.4634
#
# EPOCH[5] - STEP[90]                         	Generator_loss:0.9919                         	L1_loss:0.1793                         	Discriminator_loss:1.2497
#
# EPOCH[5] - STEP[100]                         	Generator_loss:1.3149                         	L1_loss:0.2075                         	Discriminator_loss:1.0299
#
# EPOCH[5] - STEP[110]                         	Generator_loss:0.9986                         	L1_loss:0.1852                         	Discriminator_loss:0.8859
#
# EPOCH[5] - STEP[120]                         	Generator_loss:1.2375                         	L1_loss:0.1797                         	Discriminator_loss:0.5753
#
# EPOCH[5] - STEP[130]                         	Generator_loss:2.5993                         	L1_loss:0.2579                         	Discriminator_loss:0.3095
#
# EPOCH[5] - STEP[140]                         	Generator_loss:2.2754                         	L1_loss:0.1986                         	Discriminator_loss:0.7441
#
# EPOCH[5] - STEP[150]                         	Generator_loss:2.4377                         	L1_loss:0.2193                         	Discriminator_loss:1.3746
#
# EPOCH[5] - STEP[160]                         	Generator_loss:1.8377                         	L1_loss:0.1982                         	Discriminator_loss:0.3624
#
# EPOCH[5] - STEP[170]                         	Generator_loss:1.5322                         	L1_loss:0.1820                         	Discriminator_loss:0.8663
#
# EPOCH[5] - STEP[180]                         	Generator_loss:2.1489                         	L1_loss:0.1985                         	Discriminator_loss:0.2834
#
# EPOCH[5] - STEP[190]                         	Generator_loss:2.5984                         	L1_loss:0.1956                         	Discriminator_loss:0.3890
#
# EPOCH[5] - STEP[200]                         	Generator_loss:2.5979                         	L1_loss:0.1538                         	Discriminator_loss:1.3004
#
# EPOCH[5] - STEP[210]                         	Generator_loss:2.4087                         	L1_loss:0.1906                         	Discriminator_loss:0.6462
#
# EPOCH[5] - STEP[220]                         	Generator_loss:2.3428                         	L1_loss:0.2242                         	Discriminator_loss:0.5403
#
# EPOCH[5] - STEP[230]                         	Generator_loss:1.8502                         	L1_loss:0.1582                         	Discriminator_loss:0.8735
#
# EPOCH[5] - STEP[240]                         	Generator_loss:1.8611                         	L1_loss:0.2035                         	Discriminator_loss:0.3422
#
# EPOCH[5] - STEP[250]                         	Generator_loss:3.0687                         	L1_loss:0.1834                         	Discriminator_loss:1.1622
#
# EPOCH[6] - STEP[10]                         	Generator_loss:1.9484                         	L1_loss:0.1901                         	Discriminator_loss:0.6372
#
# EPOCH[6] - STEP[20]                         	Generator_loss:2.3301                         	L1_loss:0.1875                         	Discriminator_loss:1.3655
#
# EPOCH[6] - STEP[30]                         	Generator_loss:1.0711                         	L1_loss:0.1877                         	Discriminator_loss:1.0845
#
# EPOCH[6] - STEP[40]                         	Generator_loss:2.4613                         	L1_loss:0.2145                         	Discriminator_loss:0.3834
#
# EPOCH[6] - STEP[50]                         	Generator_loss:2.3057                         	L1_loss:0.2264                         	Discriminator_loss:0.3614
#
# EPOCH[6] - STEP[60]                         	Generator_loss:1.9088                         	L1_loss:0.1657                         	Discriminator_loss:0.8728
#
# EPOCH[6] - STEP[70]                         	Generator_loss:1.7354                         	L1_loss:0.1870                         	Discriminator_loss:0.7152
#
# EPOCH[6] - STEP[80]                         	Generator_loss:0.6535                         	L1_loss:0.2175                         	Discriminator_loss:1.0932
#
# EPOCH[6] - STEP[90]                         	Generator_loss:2.6977                         	L1_loss:0.1756                         	Discriminator_loss:1.1954
#
# EPOCH[6] - STEP[100]                         	Generator_loss:2.0553                         	L1_loss:0.1780                         	Discriminator_loss:1.1946
#
# EPOCH[6] - STEP[110]                         	Generator_loss:2.3059                         	L1_loss:0.1834                         	Discriminator_loss:0.9035
#
# EPOCH[6] - STEP[120]                         	Generator_loss:1.1552                         	L1_loss:0.1573                         	Discriminator_loss:0.9467
#
# EPOCH[6] - STEP[130]                         	Generator_loss:0.3930                         	L1_loss:0.1878                         	Discriminator_loss:1.3469
#
# EPOCH[6] - STEP[140]                         	Generator_loss:1.3000                         	L1_loss:0.1519                         	Discriminator_loss:1.3114
#
# EPOCH[6] - STEP[150]                         	Generator_loss:2.2712                         	L1_loss:0.1587                         	Discriminator_loss:0.6363
#
# EPOCH[6] - STEP[160]                         	Generator_loss:2.4962                         	L1_loss:0.1438                         	Discriminator_loss:0.7500
#
# EPOCH[6] - STEP[170]                         	Generator_loss:2.2517                         	L1_loss:0.1848                         	Discriminator_loss:0.2795
#
# EPOCH[6] - STEP[180]                         	Generator_loss:2.3229                         	L1_loss:0.2091                         	Discriminator_loss:0.6409
#
# EPOCH[6] - STEP[190]                         	Generator_loss:1.7591                         	L1_loss:0.1791                         	Discriminator_loss:0.4513
#
# EPOCH[6] - STEP[200]                         	Generator_loss:2.7813                         	L1_loss:0.2300                         	Discriminator_loss:0.4989
#
# EPOCH[6] - STEP[210]                         	Generator_loss:3.7136                         	L1_loss:0.1633                         	Discriminator_loss:2.7349
#
# EPOCH[6] - STEP[220]                         	Generator_loss:1.4598                         	L1_loss:0.2118                         	Discriminator_loss:0.5154
#
# EPOCH[6] - STEP[230]                         	Generator_loss:1.0277                         	L1_loss:0.1910                         	Discriminator_loss:0.8146
#
# EPOCH[6] - STEP[240]                         	Generator_loss:1.2548                         	L1_loss:0.2016                         	Discriminator_loss:0.8043
#
# EPOCH[6] - STEP[250]                         	Generator_loss:0.9477                         	L1_loss:0.1981                         	Discriminator_loss:0.7772
#
# EPOCH[7] - STEP[10]                         	Generator_loss:2.3065                         	L1_loss:0.1578                         	Discriminator_loss:1.0680
#
# EPOCH[7] - STEP[20]                         	Generator_loss:0.7874                         	L1_loss:0.2542                         	Discriminator_loss:0.8672
#
# EPOCH[7] - STEP[30]                         	Generator_loss:1.6613                         	L1_loss:0.1839                         	Discriminator_loss:1.0498
#
# EPOCH[7] - STEP[40]                         	Generator_loss:1.5891                         	L1_loss:0.2122                         	Discriminator_loss:0.4625
#
# EPOCH[7] - STEP[50]                         	Generator_loss:2.2694                         	L1_loss:0.1452                         	Discriminator_loss:0.7373
#
# EPOCH[7] - STEP[60]                         	Generator_loss:1.1886                         	L1_loss:0.1908                         	Discriminator_loss:0.6117
#
# EPOCH[7] - STEP[70]                         	Generator_loss:1.2439                         	L1_loss:0.1791                         	Discriminator_loss:0.6248
#
# EPOCH[7] - STEP[80]                         	Generator_loss:1.5555                         	L1_loss:0.1908                         	Discriminator_loss:0.6812
#
# EPOCH[7] - STEP[90]                         	Generator_loss:1.3026                         	L1_loss:0.1964                         	Discriminator_loss:0.5624
#
# EPOCH[7] - STEP[100]                         	Generator_loss:0.9234                         	L1_loss:0.2055                         	Discriminator_loss:0.9742
#
# EPOCH[7] - STEP[110]                         	Generator_loss:0.9095                         	L1_loss:0.2000                         	Discriminator_loss:0.8293
#
# EPOCH[7] - STEP[120]                         	Generator_loss:1.7838                         	L1_loss:0.2009                         	Discriminator_loss:0.4220
#
# EPOCH[7] - STEP[130]                         	Generator_loss:1.8144                         	L1_loss:0.1948                         	Discriminator_loss:0.6950
#
# EPOCH[7] - STEP[140]                         	Generator_loss:1.1040                         	L1_loss:0.1991                         	Discriminator_loss:0.6411
#
# EPOCH[7] - STEP[150]                         	Generator_loss:2.0857                         	L1_loss:0.1795                         	Discriminator_loss:0.7906
#
# EPOCH[7] - STEP[160]                         	Generator_loss:1.2893                         	L1_loss:0.1756                         	Discriminator_loss:0.5437
#
# EPOCH[7] - STEP[170]                         	Generator_loss:1.8132                         	L1_loss:0.1675                         	Discriminator_loss:0.5533
#
# EPOCH[7] - STEP[180]                         	Generator_loss:0.8928                         	L1_loss:0.1520                         	Discriminator_loss:1.3411
#
# EPOCH[7] - STEP[190]                         	Generator_loss:1.5754                         	L1_loss:0.1631                         	Discriminator_loss:0.5363
#
# EPOCH[7] - STEP[200]                         	Generator_loss:3.1242                         	L1_loss:0.1997                         	Discriminator_loss:1.1034
#
# EPOCH[7] - STEP[210]                         	Generator_loss:0.7536                         	L1_loss:0.2039                         	Discriminator_loss:1.0999
#
# EPOCH[7] - STEP[220]                         	Generator_loss:2.2446                         	L1_loss:0.1657                         	Discriminator_loss:0.4983
#
# EPOCH[7] - STEP[230]                         	Generator_loss:1.6047                         	L1_loss:0.1556                         	Discriminator_loss:0.7965
#
# EPOCH[7] - STEP[240]                         	Generator_loss:2.1317                         	L1_loss:0.1744                         	Discriminator_loss:0.7718
#
# EPOCH[7] - STEP[250]                         	Generator_loss:1.8033                         	L1_loss:0.1898                         	Discriminator_loss:0.3103
#
# EPOCH[8] - STEP[10]                         	Generator_loss:3.4254                         	L1_loss:0.1469                         	Discriminator_loss:1.9582
#
# EPOCH[8] - STEP[20]                         	Generator_loss:2.4587                         	L1_loss:0.1784                         	Discriminator_loss:0.5511
#
# EPOCH[8] - STEP[30]                         	Generator_loss:1.6214                         	L1_loss:0.2179                         	Discriminator_loss:0.5777
#
# EPOCH[8] - STEP[40]                         	Generator_loss:1.2739                         	L1_loss:0.2051                         	Discriminator_loss:0.6189
#
# EPOCH[8] - STEP[50]                         	Generator_loss:2.1099                         	L1_loss:0.1698                         	Discriminator_loss:0.5857
#
# EPOCH[8] - STEP[60]                         	Generator_loss:1.1356                         	L1_loss:0.1673                         	Discriminator_loss:0.5888
#
# EPOCH[8] - STEP[70]                         	Generator_loss:0.6884                         	L1_loss:0.2145                         	Discriminator_loss:1.3305
#
# EPOCH[8] - STEP[80]                         	Generator_loss:2.2469                         	L1_loss:0.2173                         	Discriminator_loss:0.3121
#
# EPOCH[8] - STEP[90]                         	Generator_loss:1.6645                         	L1_loss:0.1563                         	Discriminator_loss:0.5517
#
# EPOCH[8] - STEP[100]                         	Generator_loss:2.2598                         	L1_loss:0.1890                         	Discriminator_loss:0.7278
#
# EPOCH[8] - STEP[110]                         	Generator_loss:0.5359                         	L1_loss:0.1946                         	Discriminator_loss:1.1950
#
# EPOCH[8] - STEP[120]                         	Generator_loss:0.7043                         	L1_loss:0.1990                         	Discriminator_loss:0.8516
#
# EPOCH[8] - STEP[130]                         	Generator_loss:1.7959                         	L1_loss:0.1989                         	Discriminator_loss:0.4959
#
# EPOCH[8] - STEP[140]                         	Generator_loss:0.5357                         	L1_loss:0.1777                         	Discriminator_loss:1.2244
#
# EPOCH[8] - STEP[150]                         	Generator_loss:1.3248                         	L1_loss:0.2006                         	Discriminator_loss:1.4205
#
# EPOCH[8] - STEP[160]                         	Generator_loss:1.7218                         	L1_loss:0.2089                         	Discriminator_loss:0.6286
#
# EPOCH[8] - STEP[170]                         	Generator_loss:2.8676                         	L1_loss:0.2137                         	Discriminator_loss:1.2165
#
# EPOCH[8] - STEP[180]                         	Generator_loss:1.6640                         	L1_loss:0.1827                         	Discriminator_loss:0.7302
#
# EPOCH[8] - STEP[190]                         	Generator_loss:1.4430                         	L1_loss:0.1628                         	Discriminator_loss:0.7116
#
# EPOCH[8] - STEP[200]                         	Generator_loss:0.8427                         	L1_loss:0.2008                         	Discriminator_loss:0.9352
#
# EPOCH[8] - STEP[210]                         	Generator_loss:3.2969                         	L1_loss:0.1715                         	Discriminator_loss:1.8511
#
# EPOCH[8] - STEP[220]                         	Generator_loss:1.9797                         	L1_loss:0.1708                         	Discriminator_loss:0.4038
#
# EPOCH[8] - STEP[230]                         	Generator_loss:2.0301                         	L1_loss:0.2002                         	Discriminator_loss:0.4627
#
# EPOCH[8] - STEP[240]                         	Generator_loss:1.5588                         	L1_loss:0.1747                         	Discriminator_loss:1.0942
#
# EPOCH[8] - STEP[250]                         	Generator_loss:1.3387                         	L1_loss:0.1633                         	Discriminator_loss:0.4722
#
# EPOCH[9] - STEP[10]                         	Generator_loss:3.4587                         	L1_loss:0.2199                         	Discriminator_loss:0.4120
#
# EPOCH[9] - STEP[20]                         	Generator_loss:0.4915                         	L1_loss:0.1915                         	Discriminator_loss:2.3543
#
# EPOCH[9] - STEP[30]                         	Generator_loss:1.0129                         	L1_loss:0.1619                         	Discriminator_loss:0.8605
#
# EPOCH[9] - STEP[40]                         	Generator_loss:1.2054                         	L1_loss:0.2504                         	Discriminator_loss:0.5156
#
# EPOCH[9] - STEP[50]                         	Generator_loss:2.5593                         	L1_loss:0.1873                         	Discriminator_loss:0.4824
#
# EPOCH[9] - STEP[60]                         	Generator_loss:1.1639                         	L1_loss:0.2226                         	Discriminator_loss:0.4902
#
# EPOCH[9] - STEP[70]                         	Generator_loss:1.5739                         	L1_loss:0.2233                         	Discriminator_loss:0.6569
#
# EPOCH[9] - STEP[80]                         	Generator_loss:2.1424                         	L1_loss:0.1488                         	Discriminator_loss:0.6702
#
# EPOCH[9] - STEP[90]                         	Generator_loss:1.8645                         	L1_loss:0.1844                         	Discriminator_loss:0.8055
#
# EPOCH[9] - STEP[100]                         	Generator_loss:1.5406                         	L1_loss:0.1720                         	Discriminator_loss:0.8505
#
# EPOCH[9] - STEP[110]                         	Generator_loss:1.4671                         	L1_loss:0.2110                         	Discriminator_loss:0.7100
#
# EPOCH[9] - STEP[120]                         	Generator_loss:1.1803                         	L1_loss:0.1693                         	Discriminator_loss:0.7829
#
# EPOCH[9] - STEP[130]                         	Generator_loss:1.3839                         	L1_loss:0.1730                         	Discriminator_loss:0.6780
#
# EPOCH[9] - STEP[140]                         	Generator_loss:1.2228                         	L1_loss:0.2009                         	Discriminator_loss:0.8022
#
# EPOCH[9] - STEP[150]                         	Generator_loss:0.6817                         	L1_loss:0.1601                         	Discriminator_loss:1.0677
#
# EPOCH[9] - STEP[160]                         	Generator_loss:0.5831                         	L1_loss:0.1803                         	Discriminator_loss:1.2442
#
# EPOCH[9] - STEP[170]                         	Generator_loss:1.4939                         	L1_loss:0.1673                         	Discriminator_loss:0.7851
#
# EPOCH[9] - STEP[180]                         	Generator_loss:2.5234                         	L1_loss:0.1547                         	Discriminator_loss:1.0403
#
# EPOCH[9] - STEP[190]                         	Generator_loss:1.3925                         	L1_loss:0.1949                         	Discriminator_loss:0.5978
#
# EPOCH[9] - STEP[200]                         	Generator_loss:2.7140                         	L1_loss:0.1996                         	Discriminator_loss:0.5628
#
# EPOCH[9] - STEP[210]                         	Generator_loss:1.2779                         	L1_loss:0.1832                         	Discriminator_loss:0.5914
#
# EPOCH[9] - STEP[220]                         	Generator_loss:0.9525                         	L1_loss:0.1394                         	Discriminator_loss:1.0511
#
# EPOCH[9] - STEP[230]                         	Generator_loss:2.1759                         	L1_loss:0.1780                         	Discriminator_loss:0.5182
#
# EPOCH[9] - STEP[240]                         	Generator_loss:0.8201                         	L1_loss:0.2071                         	Discriminator_loss:0.7693
#
# EPOCH[9] - STEP[250]                         	Generator_loss:2.2372                         	L1_loss:0.1659                         	Discriminator_loss:0.4790
#
# EPOCH[10] - STEP[10]                         	Generator_loss:2.5092                         	L1_loss:0.1918                         	Discriminator_loss:0.8944
#
# EPOCH[10] - STEP[20]                         	Generator_loss:2.6529                         	L1_loss:0.1662                         	Discriminator_loss:1.3299
#
# EPOCH[10] - STEP[30]                         	Generator_loss:2.6132                         	L1_loss:0.1691                         	Discriminator_loss:0.7674
#
# EPOCH[10] - STEP[40]                         	Generator_loss:3.0194                         	L1_loss:0.1615                         	Discriminator_loss:1.5136
#
# EPOCH[10] - STEP[50]                         	Generator_loss:3.0961                         	L1_loss:0.2096                         	Discriminator_loss:0.4646
#
# EPOCH[10] - STEP[60]                         	Generator_loss:2.7962                         	L1_loss:0.1635                         	Discriminator_loss:1.4680
#
# EPOCH[10] - STEP[70]                         	Generator_loss:3.2094                         	L1_loss:0.1863                         	Discriminator_loss:0.8830
#
# EPOCH[10] - STEP[80]                         	Generator_loss:3.6379                         	L1_loss:0.1673                         	Discriminator_loss:1.2452
#
# EPOCH[10] - STEP[90]                         	Generator_loss:2.3530                         	L1_loss:0.1692                         	Discriminator_loss:0.6313
#
# EPOCH[10] - STEP[100]                         	Generator_loss:2.0965                         	L1_loss:0.1733                         	Discriminator_loss:0.9707
#
# EPOCH[10] - STEP[110]                         	Generator_loss:1.1305                         	L1_loss:0.2158                         	Discriminator_loss:0.5986
#
# EPOCH[10] - STEP[120]                         	Generator_loss:2.1149                         	L1_loss:0.2512                         	Discriminator_loss:0.4102
#
# EPOCH[10] - STEP[130]                         	Generator_loss:2.3648                         	L1_loss:0.1912                         	Discriminator_loss:0.7308
#
# EPOCH[10] - STEP[140]                         	Generator_loss:1.7902                         	L1_loss:0.2393                         	Discriminator_loss:0.8548
#
# EPOCH[10] - STEP[150]                         	Generator_loss:1.0264                         	L1_loss:0.1599                         	Discriminator_loss:0.9187
#
# EPOCH[10] - STEP[160]                         	Generator_loss:1.1249                         	L1_loss:0.1866                         	Discriminator_loss:0.5846
#
# EPOCH[10] - STEP[170]                         	Generator_loss:1.8981                         	L1_loss:0.1849                         	Discriminator_loss:0.4178
#
# EPOCH[10] - STEP[180]                         	Generator_loss:1.6986                         	L1_loss:0.1647                         	Discriminator_loss:1.0403
#
# EPOCH[10] - STEP[190]                         	Generator_loss:1.6211                         	L1_loss:0.1866                         	Discriminator_loss:0.3978
#
# EPOCH[10] - STEP[200]                         	Generator_loss:2.1255                         	L1_loss:0.1669                         	Discriminator_loss:1.0238
#
# EPOCH[10] - STEP[210]                         	Generator_loss:2.0014                         	L1_loss:0.1635                         	Discriminator_loss:0.3182
#
# EPOCH[10] - STEP[220]                         	Generator_loss:1.1385                         	L1_loss:0.1764                         	Discriminator_loss:2.5278
#
# EPOCH[10] - STEP[230]                         	Generator_loss:0.2949                         	L1_loss:0.1774                         	Discriminator_loss:1.7934
#
# EPOCH[10] - STEP[240]                         	Generator_loss:2.8793                         	L1_loss:0.1839                         	Discriminator_loss:0.5253
#
# EPOCH[10] - STEP[250]                         	Generator_loss:1.8444                         	L1_loss:0.1696                         	Discriminator_loss:0.5371

# %%
def show_history(history):
    plt.figure(figsize=(10, 4))
    plt.plot(history['g_loss'], 'b-', label='Generator loss')
    plt.plot(history['l1_loss'], 'r--', label='L1 loss')
    plt.plot(history['d_loss'], 'g--', label='Discriminator loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Unet Loss')
   
    plt.show()

show_history(history_aug)

# %% [markdown]
# epoch 10회 동안 생성자의 손실값 범위가 편별자의 손실값 범위보다 높다. epoch이 진행됨에 따라 생성자의 성능이 좋은지는 더 테스트 해보아야할 것 같다.
#
# 그리고 이미지셋에 증강을 적용한것과 적용하지 않는 경우에 대해 훈련을 진행했을때 epoch 10회에 대한 로스값은 큰차이는 없었다. 아래의 그래프와 표를 통해 확인할 수 있다. 이미지 증강의 효과또한 epoch에 따라 달라지는지 체크해볼 부분인것 같다.

# %%
#show_history(history_org, history_aug )

# %% [markdown]
# 데이터셋에따라 epoch 10회에 대한 최종 loss를 알아보면 아래와 같다.
#
# |데이터셋|Generator loss|L1 loss|Disciminator loss|
# |:---|:---|---|---|
# |ep  10 - Original Image Dataset | 1.6063  | 0.1300|0.4485 |
# |ep  10 - Augmentation Image Dataset |1.1028| 0.1450 | 0.6864|

# %% [markdown]
# ## Generator 모델 테스트

# %%
test_path = '/content/cityscapes/val/'

def test_generator(test_ind):    
    f = test_path + os.listdir(test_path)[test_ind]
    sketch, colored = load_img(f)

    pred = generator(tf.expand_dims(sketch, 0))
    pred = denormalize(pred)

    plt.figure(figsize=(20,10))
    plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
    plt.subplot(1,3,2); plt.imshow(pred[0])
    plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %%
test_generator(1)

# %%
test_generator(2)

# %% [markdown]
# ### 추가 테스트 결과
#
# - epoch 50회
# ![ㅇ](https://github.com/riverlike/Aiffel_Project/blob/main/Exploration/Exp17/data/50.png?raw=true)
#
# - epoch 100회
# ![ㅇ](https://github.com/riverlike/Aiffel_Project/blob/main/Exploration/Exp17/data/100.png?raw=true)

# %% [markdown]
# # Reference
# - [Tensorflow Pix2Pix Tutorial](https://www.tensorflow.org/tutorials/generative/pix2pix?hl=ko)
#
# - https://www.secmem.org/blog/2020/07/19/pix2pix/
